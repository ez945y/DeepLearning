# %%
from torchvision import models
adlexnet = models.AlexNet()
# Out:
# ['AlexNet',
#  'DenseNet',
#  'EfficientNet',
#  'GoogLeNet',
#  'GoogLeNetOutputs',
#  'Inception3',
#  'InceptionOutputs',
#  'MNASNet',
#  'MobileNetV2',
#  'MobileNetV3',
#  'RegNet',
#  'ResNet',
#  'ShuffleNetV2',
#  'SqueezeNet',
#  'VGG',
#  '_GoogLeNetOutputs',
#  '_InceptionOutputs',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_utils',
#  'alexnet',
#  'densenet',
#  'densenet121',
#  'densenet161',
#  'densenet169',
#  'densenet201',
#  'detection',
#  'efficientnet',
#  'efficientnet_b0',
#  'efficientnet_b1',
#  'efficientnet_b2',
#  'efficientnet_b3',
#  'efficientnet_b4',
#  'efficientnet_b5',
#  'efficientnet_b6',
#  'efficientnet_b7',
#  'feature_extraction',
#  'googlenet',
#  'inception',
#  'inception_v3',
#  'mnasnet',
#  'mnasnet0_5',
#  'mnasnet0_75',
#  'mnasnet1_0',
#  'mnasnet1_3',
#  'mobilenet',
#  'mobilenet_v2',
#  'mobilenet_v3_large',
# ...

# %%
from torchvision import models
resnet = models.resnet101(pretrained=True)
resnet
# Out:
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to C:\Users\admin/.cache\torch\hub\checkpoints\resnet101-63fe2227.pth
# 14.0%IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 32.2%IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 56.2%IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# ...

# %%
from torchvision import transforms
preprocess = transforms.Compose([
    transfroms.Resize(256),
    transfroms.CenterCrop(224),
    transfroms.ToTensor(),
    transfroms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )])

# %%
from PIL import Image

img = Image.open("../dlwpt-code-master/data/p1ch2/bobby.jpg")
img_t = preprocess(img)
img_t.shape
# Out:
# torch.Size([3, 224, 224])

# %%
from torchvision import transforms
from PIL import Image
import torch
preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )])

img = Image.open("../dlwpt-code-master/data/p1ch2/bobby.jpg")
img.show()
img_t = preprocess(img)
batch_t = torch.unsqueeze(img_t, 0)
resnet.eval()
out = resnet(batch_t)
with open("../dlwpt-code-master/data/p1ch2/imagenet_classes.txt") as f:
    labels = [line.strip() for line in f.readlines()]
index = torch.max(out,1)
percentage = torch.nn.functional.softmax(out, dim=1)[0] * 100
#labels[int(index[0])],percentage[int(index[0])].item()
_, indices = torch.sort(out,descending =True)
[(labels[idx], percentage[idx].item()) for idx in indices[0][:5]]
# Out:
# [('golden retriever', 96.57185363769531),
#  ('Labrador retriever', 2.6082706451416016),
#  ('cocker spaniel, English cocker spaniel, cocker', 0.2699621915817261),
#  ('redbone', 0.17958936095237732),
#  ('tennis ball', 0.10991999506950378)]

# %%
from . cyclegan.ipynb import ResNetGenerator
netG = ResNetGenerator()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3232\941056534.py in <module>
# ----> 1 from . cyclegan.ipynb import ResNetGenerator
#       2 netG = ResNetGenerator()
#
# ModuleNotFoundError: No module named '__main__.cyclegan'; '__main__' is not a package
